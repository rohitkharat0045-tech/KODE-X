# %%
numbers = [int(input("enter a number"))for i in range(5)]
print(sum(numbers))
print(sum(numbers)/len(numbers))
# Out:
# 15
# 3.0

# %%
numbers=[5,12,7,20,3]
largest=None
for i in numbers:
    if largest is None or i > largest:
        largest=i
print(largest)
# Out:
# 20

# %%
numbers=[2,5,8,11,14,17]
count=len([num for num in numbers if num %2==0])
print(count)
# Out:
# 3

# %%
name=input("enter the input")
print(name[::-1])
# Out:
# tihor

# %%
a=input("enter")
words=a.split()
print(len(words))
# Out:
# 2

# %%
numbers=[1,2,3,2,4,5,3]
print(list(set(numbers)))
# Out:
# [1, 2, 3, 4, 5]

# %%
marks={
    "rahul":85,
    "amit":78,
    "tanvi":92
}
for name in marks:
    print(f"{name}scored {marks [name]}")
# Out:
# rahulscored 85
# amitscored 78
# tanviscored 92

# %%
password=input("enter a password")

if password=="python123":
    print("access granted")
else:
    print("access denied")
# Out:
# access granted

# %%
num=int(input("enter number"))
for i in range(1,11):
    print(f"{num} X {i}={num*i}")
# Out:
# 5 X 1=5
# 5 X 2=10
# 5 X 3=15
# 5 X 4=20
# 5 X 5=25
# 5 X 6=30
# 5 X 7=35
# 5 X 8=40
# 5 X 9=45
# 5 X 10=50

# %%
namew=input("inter your name")
age=input("inter your age")
city=input("inter your city")

user={
    "name":name,
    "age":age,
    "city":city
}
print(user)
# Out:
# {'name': 'tanvi', 'age': '21', 'city': 'jalbna'}
